# %%
import pandas as pd

# %%
data = [[1,2,3], [4,5,6], [7,8,9]]
data
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
list('321')
# Out:
# ['3', '2', '1']

# %%
df = pd.DataFrame(data, list('321'), list('ZYX'))
df
# Out:
#    Z  Y  X
# 3  1  2  3
# 2  4  5  6
# 1  7  8  9

# %%
df.sort_index(inplace = True)
df #organiza pelo índice das linhas
# Out:
#    Z  Y  X
# 1  7  8  9
# 2  4  5  6
# 3  1  2  3

# %%
df.sort_index(inplace = True, axis = 1)
df #organiza pelo índice das linhas e colunas
# Out:
#    X  Y  Z
# 1  9  8  7
# 2  6  5  4
# 3  3  2  1

# %%
df.sort_values(by = 'X', inplace = True)
df
# Out:
#    X  Y  Z
# 3  3  2  1
# 2  6  5  4
# 1  9  8  7

# %%
df.sort_values(by = '3', axis = 1, inplace = True)
df
# Out:
#    Z  Y  X
# 3  1  2  3
# 2  4  5  6
# 1  7  8  9

# %%
data2 = [['Ary', 'M', '21'], ['Cátia', 'F', '19'], ['Carlos', 'M', '50'], ['Beto', 'M', '29'],['Bruna', 'F', '31'],['Ana', 'F', '42']]
data2
# Out:
# [['Ary', 'M', '21'],
#  ['Cátia', 'F', '19'],
#  ['Carlos', 'M', '50'],
#  ['Beto', 'M', '29'],
#  ['Bruna', 'F', '31'],
#  ['Ana', 'F', '42']]

# %%
list('012345')
# Out:
# ['0', '1', '2', '3', '4', '5']

# %%
df2 = pd.DataFrame(data2, list('012345'), list('nsi'))
df2
# Out:
#         n  s   i
# 0     Ary  M  21
# 1   Cátia  F  19
# 2  Carlos  M  50
# 3    Beto  M  29
# 4   Bruna  F  31
# 5     Ana  F  42

# %%
df3 = df2.sort_values(by = ['s', 'n'])
df3
# Out:
#         n  s   i
# 5     Ana  F  42
# 4   Bruna  F  31
# 1   Cátia  F  19
# 0     Ary  M  21
# 3    Beto  M  29
# 2  Carlos  M  50
